# %% [markdown]
# # **Conformal Geometric Algebra - Summary**
#
# ![image.png](attachment:ad105724-c6d4-44b4-94c2-048a0a5202b9.png)
#
# ![image.png](attachment:d66ae508-edc0-4cb3-9925-b486d5e26ac4.png)
#
# ![image.png](attachment:4139ae6c-473a-4433-82af-86f81b314c41.png)
