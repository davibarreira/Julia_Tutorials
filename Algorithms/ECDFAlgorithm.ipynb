# %% [markdown]
# ## Multivariate Empirical CDF Algorithm

# %% [markdown]
# This algorithm uses Divide and Conquer in order to calculate the multivariate empirical
# cdf, with $O(n\log_2^{(d-1)} n)$.

# %% [markdown]
# Algorithm based on
# Lee, D., & Joe, H. (2018). Efficient computation of multivariate empirical distribution functions at the observed values. Computational Statistics, 33(3), 1413-1428.

# %%
using LinearAlgebra
using Random
using CairoMakie
using Distances
CairoMakie.activate!(type = "svg")
using Debugger
using StatsBase
using BenchmarkTools
using Random

# %%
x = collect(1:8)
y = [8,4,3,6,5,1,2,7]*10
p = ones(8)
# p = [1,1,1,1,0,0,1,1]

N = 100
x = rand(N)
y = rand(N)
v = sortperm(x)
x = x[v]
y = y[v]
p = normalize!(rand(N),1)
bruteecdf(x,y,p) ≈ bivariatedominance(x,y,p)
# Out:
# true

# %%
function bruteecdf(x,y,p=fill(1/length(y),length(y)))
    n = length(y)
    z = zeros(n)
    for i in 1:n
        xbool = x[i] .≥ x[1:end]
        ybool = y[i] .≥ y[1:end]
        z[i] = (xbool .* ybool) ⋅ p
    end
    return z
end
# Out:
# bruteecdf (generic function with 2 methods)

# %%
function bivariatedominance(x,y,p=fill(1/length(y),length(y)))
    function Merge!(y1,y2)
        y1,y2
        N1 = length(y1)
        N2 = length(y2)
        N  = N1 + N2
        i,j,k,b = 1,1,1,0
        y = zeros(Int, N)
        while i ≤ N1 && j ≤ N2
            if y1[i] ≤ y2[j]
                y[k]  = y1[i]
                b = b+p[y[k]]
                i = i+1
            else
                y[k] = y2[j]
                z[y2[j]] = z[y2[j]] + b
                j = j+1
            end
            k = k+1
        end
        if i ≤ N1
            y[k:end] = y1[i:end]
        end

        if j ≤ N2
            y[k:end] = y2[j:end]
            z[y[k:end]] = z[y[k:end]] .+ b
        end
        return y
    end

    function Sort!(y)
        N = length(y)
        if N == 1
            return y
        else
            m = floor(Int,N/2)
            y1= Sort!(y[1:m])
            y2= Sort!(y[m+1:N])
            y = Merge!(y1,y2)
            return y
        end
    end
    
#     @assert issorted(x)
    v = sortperm(x)
    yᵣ = sortperm(y[v])
#     yᵣ = sortperm(y)
    z = zeros(length(y))
    Sort!(yᵣ)
    
    return z.+p
end
# Out:
# bivariatedominance (generic function with 2 methods)

# %%
nonunique2!(r, dims=1)
# Out:
# MethodError: no method matching nonunique2!(::Matrix{Int64}; dims=1)
# Closest candidates are:
#   nonunique2!(::AbstractArray{T, N} where N) where T at In[567]:1 got unsupported keyword argument "dims"
#
# Stacktrace:
#  [1] top-level scope
#    @ In[596]:1
#  [2] eval
#    @ ./boot.jl:360 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1116

# %%
function nonunique2!(x::AbstractArray{T}) where T
    sort!(x)
    duplicatedvector = T[]
    for i=2:length(x)
        if (isequal(x[i],x[i-1]) && (length(duplicatedvector)==0 || !isequal(duplicatedvector[end], x[i])))
            push!(duplicatedvector,x[i])
        end
    end
    duplicatedvector
end
# Out:
# nonunique2! (generic function with 1 method)

# %%
Random.seed!(10)
r = rand([1,2,3,4],4,2)
d = sortslices(r,dims=1)
# d = sortslices(rand(10,2),dims=1)
v = sortperm(collect(eachrow(r)))
r[v,:]
# Out:
# 4×2 Matrix{Int64}:
#  1  2
#  1  4
#  4  1
#  4  1

# %%
r
# Out:
# 4×2 Matrix{Int64}:
#  1  4
#  1  2
#  4  1
#  4  1

# %%
x, y = d[:,1], d[:,2]
d
# Out:
# 4×2 Matrix{Int64}:
#  1  2
#  1  4
#  4  1
#  4  1

# %%
bivariatedominance(x,y) ≈ bruteecdf(x,y)
# Out:
# false

# %%
bivariatedominance(x,y)
# Out:
# 4-element Vector{Float64}:
#  0.25
#  0.5
#  0.25
#  0.5

# %%
bruteecdf(x,y)
# Out:
# 4-element Vector{Float64}:
#  0.25
#  0.5
#  0.5
#  0.5

# %%
# Out:
# Sort (generic function with 1 method)

# %%
U = zeros(10,10)
U[1,begin]=1
for i in 1:9
    U[i+1,:] = ones(10)*i
end

# %%
using LinearAlgebra, BandedMatrices
L = 2
T = 1
c = 1
d = 1
Δx = 0.1
Δt = 0.1
f(a) = sin(π*a/2)^2
u⁰ = f.(0:Δx:L)
ω = c*Δt/(Δx^2)
ζ = ω + 1 - d
K = BandedMatrix(-ω*Ones(length(u⁰),length(u⁰)), (1,1))
K[BandedMatrices.band(0)] .= ζ
U = zeros(length(0:Δt:T),length(u⁰))
U[1,:] = u⁰
U[1,begin] = 0
U[1,end] = 0
for i in 1:length(0:Δt:T-Δt)
    @show i
    @show K\U[i,:]
    @show U[i+1,:] = K\U[i,:]
    U[i+1,begin] = 0
    U[i+1,end] = 0
end

# plot(collect(0:Δx:L),U[end,:])
# Out:
# i = 1
# K \ U[i, :] = [0.008138140444159912, 0.008138140444159912, -0.002447174185242322, -0.020134464910654862, -0.03829802811078888, -0.052712713481386654, -0.06441468537059777, -0.0771528216079585, -0.0921273988519844, -0.10542542696277328, -0.11085085392554658, -0.10542542696277332, -0.0921273988519844, -0.07715282160795847, -0.06441468537059776, -0.052712713481386675, -0.03829802811078894, -0.020134464910654914, -0.0024471741852423266, 0.00813814044415995, 0.00813814044415995]
# U[i + 1, :] = K \ U[i, :] = [0.008138140444159912, 0.008138140444159912, -0.002447174185242322, -0.020134464910654862, -0.03829802811078888, -0.052712713481386654, -0.06441468537059777, -0.0771528216079585, -0.0921273988519844, -0.10542542696277328, -0.11085085392554658, -0.10542542696277332, -0.0921273988519844, -0.07715282160795847, -0.06441468537059776, -0.052712713481386675, -0.03829802811078894, -0.020134464910654914, -0.0024471741852423266, 0.00813814044415995, 0.00813814044415995]
# i = 2
# K \ U[i, :] = [-0.006870089476651772, -0.006870089476651772, -0.0008138140444159913, 0.006300992850760013, 0.009128253386241491, 0.006657063346560367, 0.002800081308457542, 0.002584486498956954, 0.007499687351295263, 0.01412794073753675, 0.01717079608251882, 0.014127940737536728, 0.0074996873512952434, 0.0025844864989569565, 0.0028000813084575614, 0.006657063346560382, 0.00912825338624149, 0.006300992850760002, -0.0008138140444159956, -0.006870089476651765, -0.006870089476651765]
# U[i + 1, :] = K \ U[i, :] = [-0.006870089476651772, -0.006870089476651772, -0.0008138140444159913, 0.006300992850760013, 0.009128253386241491, 0.006657063346560367, 0.002800081308457542, 0.002584486498956954, 0.007499687351295263, 0.01412794073753675, 0.01717079608251882, 0.014127940737536728, 0.0074996873512952434, 0.0025844864989569565, 0.0028000813084575614, 0.006657063346560382, 0.00912825338624149, 0.006300992850760002, -0.0008138140444159956, -0.006870089476651765, -0.006870089476651765]
# i = 3
# K \ U[i, :] = [0.0061598551129911725, 0.0061598551129911725, 0.0006870089476651774, -0.005391464760884396, -0.0067085729936255745, -0.0022299335713653282, 0.0038129330876042096, 0.0057628585281237835, 0.001691476790623879, -0.00482135047262943, -0.007925621337006984, -0.004821350472629437, 0.0016914767906238738, 0.005762858528123786, 0.0038129330876042165, -0.0022299335713653256, -0.006708572993625581, -0.0053914647608844036, 0.0006870089476651764, 0.0061598551129911795, 0.0061598551129911795]
# U[i + 1, :] = K \ U[i, :] = [0.0061598551129911725, 0.0061598551129911725, 0.0006870089476651774, -0.005391464760884396, -0.0067085729936255745, -0.0022299335713653282, 0.0038129330876042096, 0.0057628585281237835, 0.001691476790623879, -0.00482135047262943, -0.007925621337006984, -0.004821350472629437, 0.0016914767906238738, 0.005762858528123786, 0.0038129330876042165, -0.0022299335713653256, -0.006708572993625581, -0.0053914647608844036, 0.0006870089476651764, 0.0061598551129911795, 0.0061598551129911795]
# i = 4
# K \ U[i, :] = [-0.006382236223726051, -0.006382236223726051, -0.0006159855112991174, 0.005697549817660415, 0.006852681805047972, 0.0018259892867501146, -0.0048036991611613246, -0.007010981756671861, -0.002783568448322914, 0.004058265629286559, 0.007323969124872416, 0.004058265629286556, -0.002783568448322917, -0.007010981756671861, -0.004803699161161322, 0.001825989286750117, 0.006852681805047972, 0.005697549817660413, -0.0006159855112991186, -0.006382236223726049, -0.006382236223726049]
# U[i + 1, :] = K \ U[i, :] = [-0.006382236223726051, -0.006382236223726051, -0.0006159855112991174, 0.005697549817660415, 0.006852681805047972, 0.0018259892867501146, -0.0048036991611613246, -0.007010981756671861, -0.002783568448322914, 0.004058265629286559, 0.007323969124872416, 0.004058265629286556, -0.002783568448322917, -0.007010981756671861, -0.004803699161161322, 0.001825989286750117, 0.006852681805047972, 0.005697549817660413, -0.0006159855112991186, -0.006382236223726049, -0.006382236223726049]
# i = 5
# K \ U[i, :] = [0.0067600826550244615, 0.0067600826550244615, 0.0006382236223726052, -0.006060260481521945, -0.0072682390856605925, -0.001893246784643444, 0.005192393372342136, 0.007566010073101713, 0.003074714876426763, -0.0042129383518426594, -0.007693479791198078, -0.00421293835184266, 0.003074714876426763, 0.007566010073101715, 0.005192393372342139, -0.001893246784643444, -0.007268239085660595, -0.006060260481521949, 0.0006382236223726052, 0.006760082655024466, 0.006760082655024466]
# U[i + 1, :] = K \ U[i, :] = [0.0067600826550244615, 0.0067600826550244615, 0.0006382236223726052, -0.006060260481521945, -0.0072682390856605925, -0.001893246784643444, 0.005192393372342136, 0.007566010073101713, 0.003074714876426763, -0.0042129383518426594, -0.007693479791198078, -0.00421293835184266, 0.003074714876426763, 0.007566010073101715, 0.005192393372342139, -0.001893246784643444, -0.007268239085660595, -0.006060260481521949, 0.0006382236223726052, 0.006760082655024466, 0.006760082655024466]
# i = 6
# K \ U[i, :] = [-0.007195392090792117, -0.007195392090792117, -0.0006760082655024463, 0.00645556146305241, 0.007737595776707051, 0.0020088582222207003, -0.005539412876022007, -0.008067510435476922, -0.0032846985667650853, 0.004475340381069161, 0.008181332783018512, 0.004475340381069159, -0.0032846985667650858, -0.008067510435476922, -0.005539412876022007, 0.0020088582222207016, 0.007737595776707053, 0.006455561463052412, -0.0006760082655024467, -0.007195392090792119, -0.007195392090792119]
# U[i + 1, :] = K \ U[i, :] = [-0.007195392090792117, -0.007195392090792117, -0.0006760082655024463, 0.00645556146305241, 0.007737595776707051, 0.0020088582222207003, -0.005539412876022007, -0.008067510435476922, -0.0032846985667650853, 0.004475340381069161, 0.008181332783018512, 0.004475340381069159, -0.0032846985667650858, -0.008067510435476922, -0.005539412876022007, 0.0020088582222207016, 0.007737595776707053, 0.006455561463052412, -0.0006760082655024467, -0.007195392090792119, -0.007195392090792119]
# i = 7
# K \ U[i, :] = [0.007662220916360249, 0.007662220916360249, 0.0007195392090792118, -0.0068750808807307925, -0.008240176236115246, -0.0021388549330551582, 0.005900435480838018, 0.008593231701495377, 0.0034995472642050515, -0.004765214580613817, -0.008712295882925785, -0.004765214580613819, 0.00349954726420505, 0.008593231701495379, 0.00590043548083802, -0.0021388549330551582, -0.008240176236115249, -0.006875080880730795, 0.000719539209079212, 0.0076622209163602515, 0.0076622209163602515]
# U[i + 1, :] = K \ U[i, :] = [0.007662220916360249, 0.007662220916360249, 0.0007195392090792118, -0.0068750808807307925, -0.008240176236115246, -0.0021388549330551582, 0.005900435480838018, 0.008593231701495377, 0.0034995472642050515, -0.004765214580613817, -0.008712295882925785, -0.004765214580613819, 0.00349954726420505, 0.008593231701495379, 0.00590043548083802, -0.0021388549330551582, -0.008240176236115249, -0.006875080880730795, 0.000719539209079212, 0.0076622209163602515, 0.0076622209163602515]
# i = 8
# K \ U[i, :] = [-0.008160222593938962, -0.008160222593938962, -0.000766222091636025, 0.007322046581395015, 0.00877577676110412, 0.0022777478033206293, -0.006284143464477974, -0.009151934815882405, -0.003727114521553969, 0.00507486556790793, 0.009278501547523282, 0.0050748655679079295, -0.003727114521553971, -0.009151934815882405, -0.006284143464477972, 0.0022777478033206306, 0.00877577676110412, 0.007322046581395014, -0.000766222091636025, -0.00816022259393896, -0.00816022259393896]
# U[i + 1, :] = K \ U[i, :] = [-0.008160222593938962, -0.008160222593938962, -0.000766222091636025, 0.007322046581395015, 0.00877577676110412, 0.0022777478033206293, -0.006284143464477974, -0.009151934815882405, -0.003727114521553969, 0.00507486556790793, 0.009278501547523282, 0.0050748655679079295, -0.003727114521553971, -0.009151934815882405, -0.006284143464477972, 0.0022777478033206306, 0.00877577676110412, 0.007322046581395014, -0.000766222091636025, -0.00816022259393896, -0.00816022259393896]
# i = 9
# K \ U[i, :] = [0.008690650991966583, 0.008690650991966583, 0.0008160222593938964, -0.007798006523409085, -0.009346233440942483, -0.00242580459364381, 0.0066926540669666095, 0.009746873007058217, 0.003969412421679848, -0.005404749133222971, -0.009881648111693613, -0.00540474913322297, 0.00396941242167985, 0.009746873007058217, 0.006692654066966608, -0.0024258045936438105, -0.009346233440942481, -0.007798006523409083, 0.0008160222593938964, 0.008690650991966583, 0.008690650991966583]
# U[i + 1, :] = K \ U[i, :] = [0.008690650991966583, 0.008690650991966583, 0.0008160222593938964, -0.007798006523409085, -0.009346233440942483, -0.00242580459364381, 0.0066926540669666095, 0.009746873007058217, 0.003969412421679848, -0.005404749133222971, -0.009881648111693613, -0.00540474913322297, 0.00396941242167985, 0.009746873007058217, 0.006692654066966608, -0.0024258045936438105, -0.009346233440942481, -0.007798006523409083, 0.0008160222593938964, 0.008690650991966583, 0.008690650991966583]
# i = 10
# K \ U[i, :] = [-0.009255581198994443, -0.009255581198994443, -0.0008690650991966584, 0.008304913873858396, 0.009953779625395962, 0.002583489095631816, -0.007127710070399766, -0.010380464572728242, -0.004227441803034299, 0.0057560815275259575, 0.010523998243882553, 0.005756081527525957, -0.004227441803034299, -0.01038046457272824, -0.007127710070399763, 0.0025834890956318167, 0.00995377962539596, 0.008304913873858392, -0.0008690650991966588, -0.009255581198994441, -0.009255581198994441]
# U[i + 1, :] = K \ U[i, :] = [-0.009255581198994443, -0.009255581198994443, -0.0008690650991966584, 0.008304913873858396, 0.009953779625395962, 0.002583489095631816, -0.007127710070399766, -0.010380464572728242, -0.004227441803034299, 0.0057560815275259575, 0.010523998243882553, 0.005756081527525957, -0.004227441803034299, -0.01038046457272824, -0.007127710070399763, 0.0025834890956318167, 0.00995377962539596, 0.008304913873858392, -0.0008690650991966588, -0.009255581198994441, -0.009255581198994441]

# %%
U
# Out:
# 11×21 Matrix{Float64}:
#  0.0   0.0244717    0.0954915    …   0.0954915     0.0244717   0.0
#  0.0   0.00813814  -0.00244717      -0.00244717    0.00813814  0.0
#  0.0  -0.00687009  -0.000813814     -0.000813814  -0.00687009  0.0
#  0.0   0.00615986   0.000687009      0.000687009   0.00615986  0.0
#  0.0  -0.00638224  -0.000615986     -0.000615986  -0.00638224  0.0
#  0.0   0.00676008   0.000638224  …   0.000638224   0.00676008  0.0
#  0.0  -0.00719539  -0.000676008     -0.000676008  -0.00719539  0.0
#  0.0   0.00766222   0.000719539      0.000719539   0.00766222  0.0
#  0.0  -0.00816022  -0.000766222     -0.000766222  -0.00816022  0.0
#  0.0   0.00869065   0.000816022      0.000816022   0.00869065  0.0
#  0.0  -0.00925558  -0.000869065  …  -0.000869065  -0.00925558  0.0
