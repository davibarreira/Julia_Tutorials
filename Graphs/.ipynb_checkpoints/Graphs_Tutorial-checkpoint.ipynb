# %% [markdown]
# # Tutorial - Graphs with Julia
#
# The goal is not to be extensive. But showcase some of the functionalities in LightGraphs.jl.

# %%
using LightGraphs, GraphPlot, SimpleWeightedGraphs, LinearAlgebra, DataFrames, Random, CSV, Colors
ENV["COLUMNS"] = 2000
# Out:
# 2000

# %% [markdown]
# First, let's import the data_example.csv file. Suppose that each column represents a person, and each line represents an attribute.
#
# We then intend to create a graph to analyze the similarities between each person, by creating an edge when they share an attribute.

# %%
Random.seed!(7)
df = DataFrame(rand([0,1],10,20));

# %% [markdown]
# ### Creating the first graph
#
# The first step is to create the graph (object), by choosing the number of nodes that compose it.

# %%
g = SimpleWeightedGraph(ncol(df))
# Out:
# {20, 0} undirected simple Int64 graph with Float64 weights

# %% [markdown]
# Next we add the edges that connect the nodes. For our dataset, an edge must be added each time two nodes share an attribute,
# which means that we add an edge when both columns have a 1 in at least one similar row. For example, the first and second columns
# both have 1's in the first row, hence, we create an edge.

# %%
ew = Int[]
pairings = [] 
for i in 1:ncol(df), j in i+1:ncol(df) # iterate over all combinations of columns
    w = dot(df[!, i], df[!, j])        # calculate how many times (i,j) occurs
    if w > 0
        push!(ew, w)
        add_edge!(g, i, j, w)
        push!(pairings,[i,j])
    end
end

# %%
gplot(g,nodelabel=names(df),edgelinewidth=ew)
# Out:
# Compose.Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, Compose.UnitBox{Float64,Float64,Float64,Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Compose.Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.7091568464083355cx, -0.11445871928399437cy), (0.3817686799260853cx, 0.6472903084234656cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.7110029825103735cx, -0.18096015639814023cy), (0.2893676677838812cx, -0.9655025186600037cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.4244701390295335cx, 0.6234803968800486cy), (0.33648788186401674cx, -0.9441861326824335cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.7001246094267009cx, -0.1357525628623597cy), (0.9451338583755544cx, 0.1854091273807763cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.47031987899858363cx, 0.6432355238340446cy), (0.9572827055703126cx, 0.23217797994013117cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.3605702433189152cx, -0.9511701497005662cy), (0.9727851930057388cx, 0.14728938927712676cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.6990908289016764cx, -0.146908436971266cy), (0.6714079157454926cx, -0.15783718461266338cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.44643615419640714cx, 0.6266606565397157cy), (0.7084742682674517cx, -0.10564933886788594cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.3570522961669065cx, -0.9493693883740613cy), (0.7036109780527102cx, -0.2089135581517242cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.9659102346447782cx, 0.15181474885580043cy), (0.7613976032501845cx, -0.11397845580502536cy)])  …  Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.3232294488639482cx, -0.277522888846139cy), (0.3256278626232949cx, 0.032228184057382564cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.7695169012571272cx, -0.6730587058673098cy), (0.40261575341861605cx, 0.00711106756337971cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.9457608481676527cx, 0.386092529690445cy), (0.32183684366461285cx, 0.06984305751901383cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.5299870069933884cx, 0.7398892394096757cy), (0.33145011196573043cx, 0.08997902523937126cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.5536155071447151cx, 0.3364941524071127cy), (0.40599716895256766cx, 0.10353102709549772cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.4854147063798566cx, 0.15854206449084163cy), (0.32056379067252005cx, 0.06289857717039371cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.11712725782835756cx, 0.3043684022066315cy), (0.3357076943140902cx, 0.0949814857362472cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.2906609203996206cx, -0.7048482697053031cy), (0.33924186802269324cx, 0.0142605504 ...

# %%
gplot(g,nodelabel=names(df),edgelinewidth=ew,layout=circular_layout)
# Out:
# Compose.Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, Compose.UnitBox{Float64,Float64,Float64,Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Compose.Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.9912550475536558cx, 0.055213456753867324cy), (0.9598014687414979cx, 0.2538035376210801cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.9827254248593736cx, 0.05316567552200249cy), (0.8262915695155737cx, 0.5346195767704707cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.9256776758312355cx, 0.35882577328697246cy), (0.8343958348388656cx, 0.5379764733804481cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.9746211595360819cx, 0.04980877891202503cy), (0.6131640927563913cx, 0.7592082154629224cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.9181983217877078cx, 0.35424241923432115cy), (0.620643446799919cx, 0.7637915695155738cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.7694885236228427cx, 0.6273137230445779cy), (0.6273137230445779cx, 0.7694885236228427cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.9671418054925541cx, 0.045225424859373684cy), (0.34187518888239327cx, 0.90583109143578cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.9115280455430489cx, 0.3485454651270522cy), (0.3485454651270522cx, 0.9115280455430489cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.7637915695155738cx, 0.620643446799919cy), (0.35424241923432115cx, 0.9181983217877078cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.5379764733804481cx, 0.8343958348388656cy), (0.35882577328697246cx, 0.9256776758312355cy)])  …  Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.8978908407731511cx, 0.29174241923432115cy), (0.8978908407731512cx, -0.29174241923432137cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.9447865432461326cx, -0.008744952446344056cy), (0.8958430595412863cx, -0.3002720419286034cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.8951548168576589cx, -0.30901699437494723cy), (0.8951548168576589cx, -0.3090169943749476cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.7538035376210801cx, -0.5790402998461288cy), (0.8958430595412863cx, -0.31776194682129194cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.5346195767704708cx, -0.7917424192343211cy), (0.8978908407731512cx, -0.326291569515574cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.25920821546292255cx, -0.9256776758312354cy), (0.9012477373831286cx, -0.33439583483886587cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.04522542485937347cx, -0.9671418054925541cy), (0.90583109143578cx, -0.34187518888239354cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.348545465127052cx, -0.9115280455430489cy), (0.9115280455430489cx, -0.3485454651270524cy)]),  ...

# %%
centrality = betweenness_centrality(g,normalize=false).+1
alphas = centrality./maximum(centrality).*10
nodefillc = [RGBA(0.0,0.8,0.8,i) for i in alphas]
gplot(g,nodelabel=names(df),edgelinewidth=ew,nodefillc=nodefillc)
# Out:
# Compose.Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, Compose.UnitBox{Float64,Float64,Float64,Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Compose.Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.16029594456592552cx, -0.658589972666141cy), (0.5317393878116556cx, -0.30326249480327994cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.23305804281724912cx, -0.6331874968041532cy), (-0.7848893718343513cx, 0.5871810426867009cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.5347950555997415cx, -0.24696267119807302cy), (-0.7612480679613106cx, 0.6073512326964455cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.20036992277603732cx, -0.6290622284511487cy), (0.07564597966256542cx, 0.9449384869085258cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.5612333222943016cx, -0.22561806988147773cy), (0.10553713688225777cx, 0.9478893439546796cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.7561108921425342cx, 0.659108138399059cy), (0.03349049342176312cx, 0.9790091490261116cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.1920486781890531cx, -0.6311913826887956cy), (0.013994042907348802cx, -0.024502403364430506cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.5326353567952866cx, -0.25052058680630124cy), (0.08080441021304023cx, 0.0012218163688998696cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.7626829265047942cx, 0.6052777974982801cy), (-0.013268164384209302cx, 0.06126944541628719cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.08223763473803128cx, 0.9441823280084828cy), (0.03503474591109365cx, 0.08424762748091397cy)])  …  Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.62791323764282cx, 0.40369865409711236cy), (-0.16939010267906968cx, -0.24644347816736525cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.95062377264435cx, 0.10993475563815036cy), (-0.26209030676064227cx, -0.2555605300568534cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.523232779498765cx, -0.9260667671016463cy), (-0.17065345895403355cx, -0.318593593838702cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.9418901658209977cx, 0.018575943347435772cy), (-0.15861286667717855cx, -0.26769765343936697cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.5269082491468843cx, -0.5809389629416802cy), (-0.2531987751291846cx, -0.32031952247243817cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.32768252955383353cx, 0.5727634518451558cy), (-0.18283567159329278cx, -0.23452397088035537cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.5954265188017858cx, -0.24136760644622826cy), (-0.26830683931037186cx, -0.2759019990577084cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.4427434247787872cx, 0.14650220116866008cy), (-0.239165 ...

# %% [markdown]
# ### Minimum-Spanning Tree

# %%
g_mst = SimpleWeightedGraph(ncol(df))
for i in kruskal_mst(g,minimize=false)
    add_edge!(g_mst,i.src,i.dst,i.weight)
end

# %%
gplot(g_mst,nodelabel=names(df))
# Out:
# Compose.Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, Compose.UnitBox{Float64,Float64,Float64,Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Compose.Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.10043649502819078cx, -0.2722993363463927cy), (-0.30072294270195404cx, -0.6572594179371773cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.01943221498021854cx, -0.23151873506167092cy), (0.5498946038031666cx, -0.322386096245657cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.8022719581947771cx, -0.5216776707965893cy), (0.6453026073350235cx, -0.3700369315476522cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.1394926277283968cx, 0.9467443095206335cy), (0.08115157129789406cx, 0.7639266762051588cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.11307789821536078cx, -0.1821228358067959cy), (-0.21478730270140572cx, -0.07474479089772537cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.07790076149268224cx, -0.16690182493208416cy), (-0.10383739383756406cx, 0.276340776046597cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.14139536425716984cx, 0.5332648712302376cy), (-0.11649907286830315cx, 0.38725338939569476cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.04111314049114216cx, 0.6597396377777387cy), (-0.08405954316622082cx, 0.38307836250476757cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.15448228923689744cx, 0.3618151214030582cy), (-0.3519119930157578cx, 0.4854420754405067cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.3061794291444357cx, -0.75891881630072cy), (-0.23448432458209517cx, -0.942407093213371cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.03705005189990018cx, -0.26408867403456904cy), (0.06703095845451525cx, -0.3786800318330035cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.657558193463682cx, -0.3118864766573444cy), (0.9018642335355722cx, -0.2219595142297583cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.35213939192038135cx, -0.7565383423343197cy), (-0.4520345429943202cx, -0.9503123485070492cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.6601679973315469cx, -0.34080159015319467cy), (0.9449296142303812cx, -0.3904668446552808cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.12234637663142449cx, -0.2518395892218694cy), (-0.26105764283869054cx, -0.3365340578686922cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.3773655330524079cx, -0.7300920414431632cy), (-0.62244851692038cx, -0.842128073784969cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.025952280161927174cx, -0.19523132597139903cy), (0.13591953890094352cx, -0.10387058972847185cy)]), Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(-0.1303446199447071cx, -0.21807523892852518cy), (-0.546588401 ...
